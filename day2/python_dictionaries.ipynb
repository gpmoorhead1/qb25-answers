# %% [markdown]
# # Assigment 2 - Python dictionaries and file I/O
#
# ### Overview
# ------------
#
# The GTEx gene expression dataset consists of samples taken from many human subjects across a variety of tissues. From this dataset we have identified a set of highly-expressed tissue-specific genes. In this exercise, you will be pulling the expressing data for those genes but only in their primary tissue of expression and investigating how much variability exists across the sample population.
#
# Biological Learning Objectives
#
# - Use metadata to associate data with subject or sample traits
# - Use descriptive statistics to make inferences about gene expression heterogeneity
#
# Computational Learning Objectives
#
# - Create and modify a dicitionary
# - Use keys to retrieve values stored in a dictionary
# - Step through each key and value in a dictionary inside a `for` loop
# - Open and read a text file
# - Write to a text file
#
# ### Instructions
# ----------------
#
# - Save a copy of this notebook as `~/qbXX-answers/python_dictionaries.ipynb`.
# - Fill in answers in the available code/markdown cells below.
# - Remember to comment your code to help yourself and us know what each part is intended to do.

# %%
# Use this dictionary for identifying genes of interest and their corresponding tissue of interest

gene_tissue = {
    'ENSG00000042832.11': 'Thyroid',
    'ENSG00000091704.9': 'Pancreas',
    'ENSG00000118245.2': 'Testis',
    'ENSG00000122304.10': 'Testis',
    'ENSG00000122852.14': 'Lung',
    'ENSG00000132693.12': 'Liver',
    'ENSG00000134812.7': 'Stomach',
    'ENSG00000135346.8': 'Pituitary',
    'ENSG00000137392.9': 'Pancreas',
    'ENSG00000142515.14': 'Prostate',
    'ENSG00000142615.7': 'Pancreas',
    'ENSG00000142789.19': 'Pancreas',
    'ENSG00000158874.11': 'Liver',
    'ENSG00000162438.11': 'Pancreas',
    'ENSG00000164816.7': 'Small Intestine - Terminal Ileum',
    'ENSG00000164822.4': 'Small Intestine - Terminal Ileum',
    'ENSG00000168925.10': 'Pancreas',
    'ENSG00000168928.12': 'Pancreas',
    'ENSG00000170890.13': 'Pancreas',
    'ENSG00000171195.10': 'Minor Salivary Gland',
    'ENSG00000172179.11': 'Pituitary',
    'ENSG00000175535.6': 'Pancreas',
    'ENSG00000175646.3': 'Testis',
    'ENSG00000182333.14': 'Stomach',
    'ENSG00000187021.14': 'Pancreas',
    'ENSG00000203784.2': 'Testis',
    'ENSG00000204983.13': 'Pancreas',
    'ENSG00000219073.7': 'Pancreas',
    'ENSG00000229859.9': 'Stomach',
    'ENSG00000240338.5': 'Pancreas',
    'ENSG00000254647.6': 'Pancreas',
    'ENSG00000256713.7': 'Stomach',
    'ENSG00000259384.6': 'Pituitary',
    }

# %% [markdown]
# 1. Load sample metadata from "~/Data/GTEx/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt" and create a dictionary of sample metadata associating each sample ID with the tissue it was sampled from
#
#     - This file is tab-separated but some values have spaces in their text so make sure to specify `\t` in the `.split()` method
#     - There are several columns in the metadata file, but you only need to be concerned with `SAMPID` and `SMTSD`, the sample ID and sample tissue, respectively
#     - Your dictionary should use the `SAMPID` as the key and `SMTSD` as the value

# %%
metadata_fname = "/Users/cmdb/Data/GTEx/GTEx_Analysis_v8_Annotations_SampleAttributesDS.txt"

# Create a dictionary to hold the metadata
metadata = {}
# Step through each line of the metadata file
with open(metadata_fname, 'r') as f:
    # Remove the newline character from the line you just read in and split it by the tab character
    for line in f:
        split = line.split('\t')
        if split[0] == 'SAMPID':
            continue
        metadata[split[0]] = split[6]
    # Add the data to your metadata dictionary, using the "SAMPID" column value as the dictionary key and the "SMTSD" column value as the dictionary value

metadata
# Out:
# {'GTEX-1117F-0003-SM-58Q7G': 'Whole Blood',
#  'GTEX-1117F-0003-SM-5DWSB': 'Whole Blood',
#  'GTEX-1117F-0003-SM-6WBT7': 'Whole Blood',
#  'GTEX-1117F-0011-R10a-SM-AHZ7F': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-1117F-0011-R10b-SM-CYKQ8': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-1117F-0226-SM-5GZZ7': 'Adipose - Subcutaneous',
#  'GTEX-1117F-0426-SM-5EGHI': 'Muscle - Skeletal',
#  'GTEX-1117F-0526-SM-5EGHJ': 'Artery - Tibial',
#  'GTEX-1117F-0626-SM-5N9CS': 'Artery - Coronary',
#  'GTEX-1117F-0726-SM-5GIEN': 'Heart - Atrial Appendage',
#  'GTEX-1117F-1326-SM-5EGHH': 'Adipose - Visceral (Omentum)',
#  'GTEX-1117F-2226-SM-5N9CH': 'Ovary',
#  'GTEX-1117F-2426-SM-5EGGH': 'Uterus',
#  'GTEX-1117F-2526-SM-5GZY6': 'Vagina',
#  'GTEX-1117F-2826-SM-5GZXL': 'Breast - Mammary Tissue',
#  'GTEX-1117F-2926-SM-5GZYI': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-1117F-3026-SM-5GZYU': 'Minor Salivary Gland',
#  'GTEX-1117F-3226-SM-5N9CT': 'Brain - Cortex',
#  'GTEX-111CU-0003-SM-58Q95': 'Whole Blood',
#  'GTEX-111CU-0003-SM-5DWTR': 'Whole Blood',
#  'GTEX-111CU-0003-SM-6WBUD': 'Whole Blood',
#  'GTEX-111CU-0126-SM-5GZWZ': 'Adrenal Gland',
#  'GTEX-111CU-0226-SM-5GZXC': 'Thyroid',
#  'GTEX-111CU-0326-SM-5GZXO': 'Lung',
#  'GTEX-111CU-0426-SM-5GZY1': 'Spleen',
#  'GTEX-111CU-0526-SM-5EGHK': 'Pancreas',
#  'GTEX-111CU-0626-SM-5EGHL': 'Esophagus - Muscularis',
#  'GTEX-111CU-0726-SM-5GZYD': 'Esophagus - Mucosa',
#  'GTEX-111CU-0826-SM-5EGIJ': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-111CU-0926-SM-5EGIK': 'Stomach',
#  'GTEX-111CU-1026-SM-5EGIL': 'Adipose - Visceral (Omentum)',
#  'GTEX-111CU-1126-SM-5EGIM': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-111CU-1226-SM-5EGIN': 'Colon - Sigmoid',
#  'GTEX-111CU-1326-SM-5NQ8L': 'Small Intestine - Terminal Ileum',
#  'GTEX-111CU-1426-SM-5GZYP': 'Colon - Transverse',
#  'GTEX-111CU-1526-SM-5N9FS': 'Prostate',
#  'GTEX-111CU-1726-SM-5EGHM': 'Testis',
#  'GTEX-111CU-1826-SM-5GZYN': 'Adipose - Subcutaneous',
#  'GTEX-111CU-1926-SM-5GZYZ': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-111CU-2026-SM-5GZZC': 'Muscle - Skeletal',
#  'GTEX-111CU-2226-SM-5N9G5': 'Nerve - Tibial',
#  'GTEX-111FC-0001-SM-58Q7U': 'Whole Blood',
#  'GTEX-111FC-0001-SM-5DWSO': 'Whole Blood',
#  'GTEX-111FC-0001-SM-6WBTJ': 'Whole Blood',
#  'GTEX-111FC-0011-R10a-SM-AHZ7K': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-111FC-0011-R10a-SM-CYKQ9': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-111FC-0126-SM-5N9DL': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-111FC-0226-SM-5N9B8': 'Adipose - Subcutaneous',
#  'GTEX-111FC-0326-SM-5GZZ1': 'Muscle - Skeletal',
#  'GTEX-111FC-0426-SM-5N9CV': 'Artery - Tibial',
#  'GTEX-111FC-0526-SM-5GZZ8': 'Nerve - Tibial',
#  'GTEX-111FC-0626-SM-5N9CU': 'Heart - Atrial Appendage',
#  'GTEX-111FC-0826-SM-5GZWO': 'Heart - Left Ventricle',
#  'GTEX-111FC-0826-SM-CYKRT': 'Heart - Left Ventricle',
#  'GTEX-111FC-1026-SM-5GZX1': 'Thyroid',
#  'GTEX-111FC-1126-SM-5GZWU': 'Lung',
#  'GTEX-111FC-1326-SM-5N9D9': 'Spleen',
#  'GTEX-111FC-1426-SM-5N9C7': 'Adipose - Subcutaneous',
#  'GTEX-111FC-1926-SM-5GZYC': 'Testis',
#  'GTEX-111FC-2026-SM-5GZYO': 'Prostate',
#  'GTEX-111FC-2526-SM-5GZXU': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-111FC-2926-SM-5GZY7': 'Minor Salivary Gland',
#  'GTEX-111FC-3026-SM-5GZYJ': 'Pituitary',
#  'GTEX-111FC-3126-SM-5GZZ2': 'Brain - Cortex',
#  'GTEX-111FC-3326-SM-5GZYV': 'Brain - Cerebellum',
#  'GTEX-111VG-0004-SM-58Q85': 'Whole Blood',
#  'GTEX-111VG-0004-SM-5DWSX': 'Whole Blood',
#  'GTEX-111VG-0004-SM-6WBTS': 'Whole Blood',
#  'GTEX-111VG-0008-SM-5Q5BG': 'Cells - Cultured fibroblasts',
#  'GTEX-111VG-0326-SM-5GZX7': 'Heart - Atrial Appendage',
#  'GTEX-111VG-0526-SM-5N9BW': 'Thyroid',
#  'GTEX-111VG-0726-SM-5GIDC': 'Lung',
#  'GTEX-111VG-1626-SM-5EGIO': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-111VG-1926-SM-5GIDO': 'Testis',
#  'GTEX-111VG-2226-SM-5N9DU': 'Colon - Transverse',
#  'GTEX-111VG-2326-SM-5N9BK': 'Adipose - Subcutaneous',
#  'GTEX-111VG-2426-SM-5GZXD': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-111VG-2526-SM-5GZXP': 'Nerve - Tibial',
#  'GTEX-111VG-2626-SM-5GZY2': 'Muscle - Skeletal',
#  'GTEX-111YS-0004-SM-58Q7Y': 'Whole Blood',
#  'GTEX-111YS-0004-SM-5DWSS': 'Whole Blood',
#  'GTEX-111YS-0004-SM-6WBTN': 'Whole Blood',
#  'GTEX-111YS-0006-SM-5NQBE': 'Whole Blood',
#  'GTEX-111YS-0008-SM-5Q5BH': 'Cells - Cultured fibroblasts',
#  'GTEX-111YS-0126-SM-5987T': 'Adrenal Gland',
#  'GTEX-111YS-0326-SM-5GZZ3': 'Heart - Atrial Appendage',
#  'GTEX-111YS-0426-SM-5987O': 'Heart - Left Ventricle',
#  'GTEX-111YS-0526-SM-5GZXJ': 'Artery - Aorta',
#  'GTEX-111YS-0626-SM-5GZXV': 'Lung',
#  'GTEX-111YS-0726-SM-5GZY8': 'Thyroid',
#  'GTEX-111YS-0826-SM-5GZYK': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-111YS-0926-SM-5EGGI': 'Esophagus - Mucosa',
#  'GTEX-111YS-1026-SM-5GZYE': 'Esophagus - Muscularis',
#  'GTEX-111YS-1126-SM-5GZYQ': 'Stomach',
#  'GTEX-111YS-1226-SM-5EGGJ': 'Pancreas',
#  'GTEX-111YS-1326-SM-5EGGK': 'Adipose - Visceral (Omentum)',
#  'GTEX-111YS-1426-SM-5GID8': 'Small Intestine - Terminal Ileum',
#  'GTEX-111YS-1526-SM-5GZYW': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-111YS-1626-SM-5GZZ9': 'Colon - Transverse',
#  'GTEX-111YS-1726-SM-5GIED': 'Prostate',
#  'GTEX-111YS-1826-SM-5GIEP': 'Colon - Sigmoid',
#  'GTEX-111YS-1926-SM-5GICC': 'Breast - Mammary Tissue',
#  'GTEX-111YS-2026-SM-5EGGL': 'Testis',
#  'GTEX-111YS-2126-SM-5EGGM': 'Nerve - Tibial',
#  'GTEX-111YS-2226-SM-5987P': 'Artery - Tibial',
#  'GTEX-111YS-2326-SM-5987L': 'Muscle - Skeletal',
#  'GTEX-111YS-2426-SM-5GZZQ': 'Adipose - Subcutaneous',
#  'GTEX-1122O-0003-SM-5Q5DL': 'Cells - EBV-transformed lymphocytes',
#  'GTEX-1122O-0004-SM-58Q7O': 'Whole Blood',
#  'GTEX-1122O-0004-SM-5DWSJ': 'Whole Blood',
#  'GTEX-1122O-0004-SM-6WBTE': 'Whole Blood',
#  'GTEX-1122O-0005-SM-5O99J': 'Whole Blood',
#  'GTEX-1122O-0008-SM-5QGR2': 'Cells - Cultured fibroblasts',
#  'GTEX-1122O-0126-SM-5GICA': 'Lung',
#  'GTEX-1122O-0226-SM-5N9DA': 'Thyroid',
#  'GTEX-1122O-0326-SM-5H124': 'Adrenal Gland',
#  'GTEX-1122O-0426-SM-5H12G': 'Artery - Coronary',
#  'GTEX-1122O-0526-SM-5N9DM': 'Spleen',
#  'GTEX-1122O-0626-SM-5N9B9': 'Heart - Atrial Appendage',
#  'GTEX-1122O-0726-SM-5GIEV': 'Pancreas',
#  'GTEX-1122O-0826-SM-5GICV': 'Heart - Left Ventricle',
#  'GTEX-1122O-0926-SM-5N9C9': 'Adipose - Visceral (Omentum)',
#  'GTEX-1122O-0926-SM-9YFLC': 'Adipose - Visceral (Omentum)',
#  'GTEX-1122O-1026-SM-9WYSF': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-1122O-1126-SM-5NQ8X': 'Artery - Aorta',
#  'GTEX-1122O-1226-SM-5H113': 'Breast - Mammary Tissue',
#  'GTEX-1122O-1326-SM-5H11F': 'Small Intestine - Terminal Ileum',
#  'GTEX-1122O-1426-SM-5H11R': 'Colon - Sigmoid',
#  'GTEX-1122O-1526-SM-5N9CL': 'Colon - Transverse',
#  'GTEX-1122O-1626-SM-5N9CX': 'Esophagus - Muscularis',
#  'GTEX-1122O-1726-SM-5GICM': 'Esophagus - Mucosa',
#  'GTEX-1122O-1826-SM-5EGIP': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-1122O-1926-SM-5EGIQ': 'Stomach',
#  'GTEX-1122O-2026-SM-5NQ91': 'Adipose - Subcutaneous',
#  'GTEX-1122O-2026-SM-9YFMG': 'Adipose - Subcutaneous',
#  'GTEX-1122O-2126-SM-5EGIR': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-1122O-2326-SM-9YFL9': 'Artery - Tibial',
#  'GTEX-1122O-2426-SM-5GIDN': 'Muscle - Skeletal',
#  'GTEX-1128S-0001-SM-58Q96': 'Whole Blood',
#  'GTEX-1128S-0001-SM-5DWTV': 'Whole Blood',
#  'GTEX-1128S-0001-SM-6WBUH': 'Whole Blood',
#  'GTEX-1128S-0005-SM-5P9HI': 'Whole Blood',
#  'GTEX-1128S-0008-SM-5Q5DP': 'Cells - Cultured fibroblasts',
#  'GTEX-1128S-0126-SM-5H12S': 'Thyroid',
#  'GTEX-1128S-0326-SM-5GZZF': 'Artery - Aorta',
#  'GTEX-1128S-0726-SM-5N9D6': 'Lung',
#  'GTEX-1128S-0826-SM-5GZZI': 'Pancreas',
#  'GTEX-1128S-0926-SM-5GZZU': 'Adipose - Visceral (Omentum)',
#  'GTEX-1128S-1426-SM-5N9EF': 'Esophagus - Mucosa',
#  'GTEX-1128S-1626-SM-5H12O': 'Colon - Transverse',
#  'GTEX-1128S-2126-SM-5H12U': 'Adipose - Subcutaneous',
#  'GTEX-1128S-2326-SM-5GZZY': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-1128S-2426-SM-5H11B': 'Muscle - Skeletal',
#  'GTEX-1128S-2526-SM-5H11N': 'Artery - Tibial',
#  'GTEX-1128S-2626-SM-5H11Z': 'Pituitary',
#  'GTEX-1128S-2726-SM-5H12C': 'Brain - Cortex',
#  'GTEX-1128S-2826-SM-5N9DI': 'Brain - Cerebellum',
#  'GTEX-113IC-0001-SM-58Q97': 'Whole Blood',
#  'GTEX-113IC-0001-SM-5DWSI': 'Whole Blood',
#  'GTEX-113IC-0001-SM-DLIPU': 'Whole Blood',
#  'GTEX-113IC-0006-SM-5NQ9C': 'Whole Blood',
#  'GTEX-113IC-0008-SM-5QGRF': 'Cells - Cultured fibroblasts',
#  'GTEX-113IC-0126-SM-5HL6T': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-113IC-0226-SM-5HL5C': 'Adipose - Subcutaneous',
#  'GTEX-113IC-0426-SM-5HL5O': 'Artery - Tibial',
#  'GTEX-113IC-0526-SM-5HL76': 'Nerve - Tibial',
#  'GTEX-113JC-0001-SM-58Q7M': 'Whole Blood',
#  'GTEX-113JC-0001-SM-5DWSH': 'Whole Blood',
#  'GTEX-113JC-0001-SM-6WBTD': 'Whole Blood',
#  'GTEX-113JC-0006-SM-5O997': 'Whole Blood',
#  'GTEX-113JC-0008-SM-5QGR6': 'Cells - Cultured fibroblasts',
#  'GTEX-113JC-0126-SM-5EGJW': 'Thyroid',
#  'GTEX-113JC-0726-SM-5GZZR': 'Adipose - Visceral (Omentum)',
#  'GTEX-113JC-0926-SM-5H114': 'Esophagus - Muscularis',
#  'GTEX-113JC-1026-SM-5H117': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-113JC-1926-SM-5N9GE': 'Vagina',
#  'GTEX-113JC-2226-SM-5EGJG': 'Uterus',
#  'GTEX-113JC-2326-SM-5EQ4E': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-113JC-2726-SM-5EGIS': 'Muscle - Skeletal',
#  'GTEX-113JC-2826-SM-5EGIT': 'Pituitary',
#  'GTEX-117XS-0001-SM-58Q7J': 'Whole Blood',
#  'GTEX-117XS-0001-SM-5DWSE': 'Whole Blood',
#  'GTEX-117XS-0001-SM-6WBTA': 'Whole Blood',
#  'GTEX-117XS-0005-SM-5PNU6': 'Whole Blood',
#  'GTEX-117XS-0008-SM-5Q5DQ': 'Cells - Cultured fibroblasts',
#  'GTEX-117XS-0011-R10a-SM-AHZ7G': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-117XS-0426-SM-5GZZN': 'Artery - Aorta',
#  'GTEX-117XS-0526-SM-5987Q': 'Thyroid',
#  'GTEX-117XS-0726-SM-5H131': 'Heart - Atrial Appendage',
#  'GTEX-117XS-1926-SM-5GICO': 'Breast - Mammary Tissue',
#  'GTEX-117XS-2026-SM-5GID1': 'Testis',
#  'GTEX-117XS-2226-SM-5GIE1': 'Colon - Sigmoid',
#  'GTEX-117XS-2526-SM-5H11G': 'Muscle - Skeletal',
#  'GTEX-117XS-2526-SM-CYKR4': 'Muscle - Skeletal',
#  'GTEX-117XS-2726-SM-5N9BL': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-117XS-2926-SM-5N9BX': 'Pituitary',
#  'GTEX-117XS-3026-SM-5N9CA': 'Brain - Cortex',
#  'GTEX-117XS-3026-SM-CYKOR': 'Brain - Cortex',
#  'GTEX-117XS-3126-SM-5GIDP': 'Brain - Cerebellum',
#  'GTEX-117YW-0003-SM-58Q99': 'Whole Blood',
#  'GTEX-117YW-0003-SM-5DWRD': 'Whole Blood',
#  'GTEX-117YW-0003-SM-6WBSY': 'Whole Blood',
#  'GTEX-117YW-0005-SM-5NQ8Z': 'Whole Blood',
#  'GTEX-117YW-0008-SM-5QGRD': 'Cells - Cultured fibroblasts',
#  'GTEX-117YW-0126-SM-5EGGN': 'Thyroid',
#  'GTEX-117YW-0226-SM-5N9CM': 'Artery - Aorta',
#  'GTEX-117YW-0326-SM-5N9CY': 'Heart - Left Ventricle',
#  'GTEX-117YW-0426-SM-5GZZZ': 'Heart - Atrial Appendage',
#  'GTEX-117YW-0526-SM-5H11C': 'Lung',
#  'GTEX-117YW-0826-SM-5H11O': 'Adipose - Visceral (Omentum)',
#  'GTEX-117YW-1426-SM-5EGGO': 'Prostate',
#  'GTEX-117YW-1526-SM-5EGGP': 'Testis',
#  'GTEX-117YW-1826-SM-5PNY5': 'Colon - Transverse',
#  'GTEX-117YW-1926-SM-5H121': 'Esophagus - Mucosa',
#  'GTEX-117YW-2026-SM-5N9BH': 'Esophagus - Muscularis',
#  'GTEX-117YW-2226-SM-5N9DB': 'Stomach',
#  'GTEX-117YW-2426-SM-5Q5AE': 'Muscle - Skeletal',
#  'GTEX-117YW-2626-SM-5GZZH': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-117YW-2726-SM-5GZZT': 'Artery - Tibial',
#  'GTEX-117YW-2826-SM-5H116': 'Pituitary',
#  'GTEX-117YW-2926-SM-5GIEQ': 'Brain - Cortex',
#  'GTEX-117YX-0001-SM-5DU4O': 'Whole Blood',
#  'GTEX-117YX-0001-SM-7DRQ6': 'Whole Blood',
#  'GTEX-117YX-0126-SM-5EGH5': 'Adrenal Gland',
#  'GTEX-117YX-0226-SM-5EGH6': 'Pancreas',
#  'GTEX-117YX-0326-SM-5GICL': 'Small Intestine - Terminal Ileum',
#  'GTEX-117YX-0526-SM-5EGJH': 'Colon - Sigmoid',
#  'GTEX-117YX-0626-SM-5EGJI': 'Heart - Atrial Appendage',
#  'GTEX-117YX-0726-SM-5GIET': 'Adipose - Visceral (Omentum)',
#  'GTEX-117YX-0826-SM-5H11J': 'Colon - Transverse',
#  'GTEX-117YX-1026-SM-5H11V': 'Stomach',
#  'GTEX-117YX-1126-SM-5H128': 'Heart - Left Ventricle',
#  'GTEX-117YX-1226-SM-5H11S': 'Thyroid',
#  'GTEX-117YX-1326-SM-5H125': 'Lung',
#  'GTEX-117YX-1426-SM-5H12H': 'Breast - Mammary Tissue',
#  'GTEX-117YX-1526-SM-5H12T': 'Prostate',
#  'GTEX-117YX-1626-SM-5GZZG': 'Esophagus - Mucosa',
#  'GTEX-117YX-1726-SM-5GZZS': 'Artery - Coronary',
#  'GTEX-117YX-1826-SM-5H12K': 'Esophagus - Muscularis',
#  'GTEX-117YX-1926-SM-5GIEC': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-117YX-2026-SM-5GIEF': 'Testis',
#  'GTEX-117YX-2126-SM-5GIEL': 'Spleen',
#  'GTEX-117YX-2226-SM-5EGJJ': 'Adipose - Subcutaneous',
#  'GTEX-117YX-2326-SM-5H12W': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-117YX-2426-SM-5GZZJ': 'Nerve - Tibial',
#  'GTEX-117YX-2526-SM-5EQ4Q': 'Muscle - Skeletal',
#  'GTEX-117YX-2626-SM-5EQ53': 'Artery - Tibial',
#  'GTEX-1192W-0001-SM-58Q7T': 'Whole Blood',
#  'GTEX-1192W-0001-SM-5DWSN': 'Whole Blood',
#  'GTEX-1192W-0001-SM-6WBTI': 'Whole Blood',
#  'GTEX-1192W-0005-SM-5NQBQ': 'Whole Blood',
#  'GTEX-1192W-0008-SM-5QGRE': 'Cells - Cultured fibroblasts',
#  'GTEX-1192W-0126-SM-5EGGS': 'Thyroid',
#  'GTEX-1192W-0226-SM-5EGGT': 'Heart - Atrial Appendage',
#  'GTEX-1192W-0826-SM-5EGHE': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-1192W-2326-SM-5N9BS': 'Testis',
#  'GTEX-1192W-2626-SM-5Q5AF': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-1192W-3026-SM-5GZZV': 'Pituitary',
#  'GTEX-1192X-0004-SM-58Q7Q': 'Whole Blood',
#  'GTEX-1192X-0004-SM-5DWSK': 'Whole Blood',
#  'GTEX-1192X-0004-SM-6WBTF': 'Whole Blood',
#  'GTEX-1192X-0005-SM-5NQC3': 'Whole Blood',
#  'GTEX-1192X-0008-SM-5Q5B7': 'Cells - Cultured fibroblasts',
#  'GTEX-1192X-0011-R10a-SM-CYKSL': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-1192X-0011-R10a-SM-DO941': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-1192X-0011-R11b-SM-DO935': 'Brain - Cerebellar Hemisphere',
#  'GTEX-1192X-0011-R5a-SM-DNZZA': 'Brain - Caudate (basal ganglia)',
#  'GTEX-1192X-0011-R6a-SM-DNZZB': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-1192X-0011-R7b-SM-DNZZC': 'Brain - Putamen (basal ganglia)',
#  'GTEX-1192X-0011-R8b-SM-DO11U': 'Brain - Hypothalamus',
#  'GTEX-1192X-0011-R9b-SM-DO934': 'Brain - Spinal cord (cervical c-1)',
#  'GTEX-1192X-0226-SM-5H12D': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-1192X-0326-SM-5H11U': 'Nerve - Tibial',
#  'GTEX-1192X-0426-SM-5GIEE': 'Muscle - Skeletal',
#  'GTEX-1192X-0726-SM-5987R': 'Heart - Atrial Appendage',
#  'GTEX-1192X-1026-SM-5H12P': 'Liver',
#  'GTEX-1192X-1126-SM-5EGGU': 'Thyroid',
#  'GTEX-1192X-1526-SM-5H11I': 'Adipose - Visceral (Omentum)',
#  'GTEX-1192X-1826-SM-5GIE2': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-1192X-2326-SM-5987X': 'Breast - Mammary Tissue',
#  'GTEX-1192X-2526-SM-59868': 'Small Intestine - Terminal Ileum',
#  'GTEX-1192X-2726-SM-5N9DN': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-1192X-2926-SM-5N9BA': 'Minor Salivary Gland',
#  'GTEX-1192X-3026-SM-5N9BM': 'Pituitary',
#  'GTEX-1192X-3126-SM-5N9BY': 'Brain - Cortex',
#  'GTEX-1192X-3226-SM-5987D': 'Brain - Cerebellum',
#  'GTEX-11DXW-0003-SM-58Q7S': 'Whole Blood',
#  'GTEX-11DXW-0003-SM-5DWSM': 'Whole Blood',
#  'GTEX-11DXW-0006-SM-5NQ7Y': 'Whole Blood',
#  'GTEX-11DXW-0008-SM-5Q59V': 'Cells - Cultured fibroblasts',
#  'GTEX-11DXW-0011-R10a-SM-AHZNX': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11DXW-0011-R1a-SM-DNZZD': 'Brain - Hippocampus',
#  'GTEX-11DXW-0011-R3b-SM-DNZZE': 'Brain - Anterior cingulate cortex (BA24)',
#  'GTEX-11DXW-0011-R5b-SM-DO11D': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11DXW-0011-R6a-SM-DO11N': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-11DXW-0011-R7b-SM-DO119': 'Brain - Putamen (basal ganglia)',
#  'GTEX-11DXW-0226-SM-5H122': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11DXW-0326-SM-5H11W': 'Adipose - Subcutaneous',
#  'GTEX-11DXW-0426-SM-5H12E': 'Nerve - Tibial',
#  'GTEX-11DXW-0526-SM-5H127': 'Artery - Tibial',
#  'GTEX-11DXW-0626-SM-5N9ER': 'Breast - Mammary Tissue',
#  'GTEX-11DXW-0726-SM-5H12J': 'Muscle - Skeletal',
#  'GTEX-11DXW-0726-SM-CYKR5': 'Muscle - Skeletal',
#  'GTEX-11DXW-0826-SM-5H118': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11DXW-1026-SM-5H11K': 'Brain - Cerebellum',
#  'GTEX-11DXW-1126-SM-5H12Q': 'Brain - Cortex',
#  'GTEX-11DXW-1126-SM-CYKSD': 'Brain - Cortex',
#  'GTEX-11DXW-1226-SM-5H133': 'Pituitary',
#  'GTEX-11DXX-0004-SM-58Q7I': 'Whole Blood',
#  'GTEX-11DXX-0004-SM-5DWSD': 'Whole Blood',
#  'GTEX-11DXX-0004-SM-6WBT9': 'Whole Blood',
#  'GTEX-11DXX-0005-SM-5NQ8B': 'Whole Blood',
#  'GTEX-11DXX-0008-SM-5Q5B8': 'Cells - Cultured fibroblasts',
#  'GTEX-11DXX-0126-SM-5EGH7': 'Adrenal Gland',
#  'GTEX-11DXX-0226-SM-5P9HL': 'Thyroid',
#  'GTEX-11DXX-0326-SM-5PNWC': 'Heart - Left Ventricle',
#  'GTEX-11DXX-0426-SM-5EQ5F': 'Artery - Aorta',
#  'GTEX-11DXX-0526-SM-5PNVR': 'Heart - Atrial Appendage',
#  'GTEX-11DXX-0626-SM-5Q5AG': 'Lung',
#  'GTEX-11DXX-0726-SM-5H12X': 'Spleen',
#  'GTEX-11DXX-0826-SM-5GZZP': 'Artery - Coronary',
#  'GTEX-11DXX-0926-SM-5H112': 'Pancreas',
#  'GTEX-11DXX-1026-SM-5H11E': 'Esophagus - Muscularis',
#  'GTEX-11DXX-1126-SM-5GZZK': 'Esophagus - Mucosa',
#  'GTEX-11DXX-1226-SM-5GICD': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11DXX-1326-SM-5GIDZ': 'Stomach',
#  'GTEX-11DXX-1426-SM-5GIDU': 'Ovary',
#  'GTEX-11DXX-1526-SM-5H115': 'Uterus',
#  'GTEX-11DXX-1626-SM-5H11H': 'Small Intestine - Terminal Ileum',
#  'GTEX-11DXX-1726-SM-5H11T': 'Vagina',
#  'GTEX-11DXX-1826-SM-5H126': 'Colon - Transverse',
#  'GTEX-11DXX-1926-SM-5EGJK': 'Colon - Sigmoid',
#  'GTEX-11DXX-2026-SM-5EGJL': 'Adipose - Visceral (Omentum)',
#  'GTEX-11DXX-2126-SM-5PNYR': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11DXX-2326-SM-5Q5A2': 'Adipose - Subcutaneous',
#  'GTEX-11DXX-2326-SM-9YFKS': 'Adipose - Subcutaneous',
#  'GTEX-11DXX-2426-SM-5GZZW': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11DXX-2526-SM-5H119': 'Nerve - Tibial',
#  'GTEX-11DXX-2626-SM-5Q5A3': 'Artery - Tibial',
#  'GTEX-11DXX-2726-SM-5PNXO': 'Muscle - Skeletal',
#  'GTEX-11DXY-0004-SM-58Q7Z': 'Whole Blood',
#  'GTEX-11DXY-0004-SM-5DWST': 'Whole Blood',
#  'GTEX-11DXY-0004-SM-6WBTO': 'Whole Blood',
#  'GTEX-11DXY-0006-SM-5NQ8N': 'Whole Blood',
#  'GTEX-11DXY-0008-SM-5QGR4': 'Cells - Cultured fibroblasts',
#  'GTEX-11DXY-0011-R10b-SM-DO12C': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11DXY-0011-R11a-SM-DNZZN': 'Brain - Cerebellar Hemisphere',
#  'GTEX-11DXY-0011-R5b-SM-DNZZL': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11DXY-0011-R6a-SM-DNZZF': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-11DXY-0011-R7a-SM-DO11L': 'Brain - Putamen (basal ganglia)',
#  'GTEX-11DXY-0011-R8a-SM-DO11M': 'Brain - Hypothalamus',
#  'GTEX-11DXY-0126-SM-5H11Q': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11DXY-0226-SM-5H123': 'Testis',
#  'GTEX-11DXY-0326-SM-5H12F': 'Adipose - Visceral (Omentum)',
#  'GTEX-11DXY-0426-SM-5H12R': 'Thyroid',
#  'GTEX-11DXY-0526-SM-5EGGQ': 'Liver',
#  'GTEX-11DXY-0826-SM-5EGGR': 'Heart - Left Ventricle',
#  'GTEX-11DXY-1026-SM-5987V': 'Heart - Atrial Appendage',
#  'GTEX-11DXY-1126-SM-5987W': 'Artery - Coronary',
#  'GTEX-11DXY-1326-SM-5987Z': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11DXY-1426-SM-5N9CN': 'Esophagus - Mucosa',
#  'GTEX-11DXY-1526-SM-5H129': 'Esophagus - Muscularis',
#  'GTEX-11DXY-1626-SM-5H12L': 'Adrenal Gland',
#  'GTEX-11DXY-2026-SM-5N9CZ': 'Colon - Sigmoid',
#  'GTEX-11DXY-2326-SM-5GICW': 'Breast - Mammary Tissue',
#  'GTEX-11DXY-2626-SM-5GIE7': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11DXY-2726-SM-5GID2': 'Muscle - Skeletal',
#  'GTEX-11DXY-3026-SM-5N9CB': 'Pituitary',
#  'GTEX-11DXY-3126-SM-5N9BT': 'Brain - Cerebellum',
#  'GTEX-11DXY-3226-SM-5GIDE': 'Brain - Cortex',
#  'GTEX-11DXZ-0003-SM-58Q7X': 'Whole Blood',
#  'GTEX-11DXZ-0003-SM-5DWSR': 'Whole Blood',
#  'GTEX-11DXZ-0003-SM-6WBTM': 'Whole Blood',
#  'GTEX-11DXZ-0003-SM-CLTG6': 'Whole Blood',
#  'GTEX-11DXZ-0006-SM-5LZZH': 'Whole Blood',
#  'GTEX-11DXZ-0126-SM-5EGGY': 'Liver',
#  'GTEX-11DXZ-0226-SM-5EGGZ': 'Adrenal Gland',
#  'GTEX-11DXZ-0326-SM-5EGH1': 'Heart - Atrial Appendage',
#  'GTEX-11DXZ-0426-SM-5987Y': 'Artery - Aorta',
#  'GTEX-11DXZ-0526-SM-5GU7J': 'Artery - Coronary',
#  'GTEX-11DXZ-0626-SM-5GU77': 'Heart - Left Ventricle',
#  'GTEX-11DXZ-0726-SM-5N9C4': 'Lung',
#  'GTEX-11DXZ-0926-SM-5N9CG': 'Thyroid',
#  'GTEX-11DXZ-1026-SM-5N9D5': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11DXZ-1226-SM-5H11L': 'Esophagus - Mucosa',
#  'GTEX-11DXZ-1326-SM-5H11X': 'Small Intestine - Terminal Ileum',
#  'GTEX-11DXZ-1426-SM-5H12A': 'Adipose - Visceral (Omentum)',
#  'GTEX-11DXZ-1626-SM-5GIDI': 'Colon - Sigmoid',
#  'GTEX-11DXZ-1726-SM-5H12M': 'Colon - Transverse',
#  'GTEX-11DXZ-1826-SM-5H12Y': 'Prostate',
#  'GTEX-11DXZ-1926-SM-5GZZL': 'Breast - Mammary Tissue',
#  'GTEX-11DXZ-2026-SM-5987S': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11DXZ-2126-SM-59881': 'Testis',
#  'GTEX-11DXZ-2226-SM-5EGH2': 'Adipose - Subcutaneous',
#  'GTEX-11DXZ-2326-SM-5EGGV': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11DXZ-2426-SM-5N9DT': 'Muscle - Skeletal',
#  'GTEX-11DXZ-2526-SM-5N9BG': 'Nerve - Tibial',
#  'GTEX-11DXZ-2626-SM-59882': 'Artery - Tibial',
#  'GTEX-11DYG-0004-SM-58Q7K': 'Whole Blood',
#  'GTEX-11DYG-0004-SM-5DWSF': 'Whole Blood',
#  'GTEX-11DYG-0004-SM-6WBTB': 'Whole Blood',
#  'GTEX-11DYG-0006-SM-5NQB2': 'Whole Blood',
#  'GTEX-11DYG-0008-SM-5QGR5': 'Cells - Cultured fibroblasts',
#  'GTEX-11DYG-0011-R10b-SM-DNZZO': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11DYG-0011-R11a-SM-DNZZP': 'Brain - Cerebellar Hemisphere',
#  'GTEX-11DYG-0011-R5a-SM-DO928': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11DYG-0011-R6a-SM-DO936': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-11DYG-0011-R7b-SM-EXUS6': 'Brain - Putamen (basal ganglia)',
#  'GTEX-11DYG-0011-R8a-SM-DO93F': 'Brain - Hypothalamus',
#  'GTEX-11DYG-0126-SM-59883': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11DYG-0426-SM-5987J': 'Nerve - Tibial',
#  'GTEX-11DYG-0826-SM-5N9GH': 'Thyroid',
#  'GTEX-11DYG-0926-SM-5EGGW': 'Artery - Coronary',
#  'GTEX-11DYG-1026-SM-5A5JQ': 'Heart - Atrial Appendage',
#  'GTEX-11DYG-1226-SM-5N9DC': 'Artery - Aorta',
#  'GTEX-11DYG-1326-SM-5N9DO': 'Esophagus - Mucosa',
#  'GTEX-11DYG-1426-SM-5A5JR': 'Esophagus - Muscularis',
#  'GTEX-11DYG-1526-SM-5A5JS': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11DYG-1926-SM-5H12I': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11DYG-2026-SM-5EGGX': 'Adipose - Visceral (Omentum)',
#  'GTEX-11DYG-2526-SM-5N9BB': 'Prostate',
#  'GTEX-11DYG-2926-SM-5H132': 'Brain - Cerebellum',
#  'GTEX-11DYG-3126-SM-5A5L6': 'Pituitary',
#  'GTEX-11DZ1-0002-SM-58Q7R': 'Whole Blood',
#  'GTEX-11DZ1-0002-SM-5DWSL': 'Whole Blood',
#  'GTEX-11DZ1-0002-SM-6WBTG': 'Whole Blood',
#  'GTEX-11DZ1-0002-SM-CLTG7': 'Whole Blood',
#  'GTEX-11DZ1-0008-SM-5QGR3': 'Cells - Cultured fibroblasts',
#  'GTEX-11DZ1-0011-R10b-SM-DO943': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11DZ1-0011-R11b-SM-DO11W': 'Brain - Cerebellar Hemisphere',
#  'GTEX-11DZ1-0011-R2a-SM-DNZZM': 'Brain - Substantia nigra',
#  'GTEX-11DZ1-0011-R3a-SM-DNZYY': 'Brain - Anterior cingulate cortex (BA24)',
#  'GTEX-11DZ1-0011-R5a-SM-DO11J': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11DZ1-0011-R6b-SM-DNZZG': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-11DZ1-0011-R7a-SM-DNZZH': 'Brain - Putamen (basal ganglia)',
#  'GTEX-11DZ1-0011-R8b-SM-DNZZI': 'Brain - Hypothalamus',
#  'GTEX-11DZ1-0011-R9a-SM-DO933': 'Brain - Spinal cord (cervical c-1)',
#  'GTEX-11DZ1-0126-SM-5985Q': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11DZ1-0226-SM-5A5KF': 'Adipose - Subcutaneous',
#  'GTEX-11DZ1-0326-SM-5N9BN': 'Breast - Mammary Tissue',
#  'GTEX-11DZ1-0426-SM-5H11A': 'Lung',
#  'GTEX-11DZ1-0926-SM-5EQ5R': 'Muscle - Skeletal',
#  'GTEX-11DZ1-2026-SM-5A5KG': 'Esophagus - Mucosa',
#  'GTEX-11DZ1-2426-SM-5GZZX': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11DZ1-2726-SM-5A5KH': 'Thyroid',
#  'GTEX-11DZ1-2926-SM-5A5KI': 'Brain - Cerebellum',
#  'GTEX-11EI6-0004-SM-58Q7L': 'Whole Blood',
#  'GTEX-11EI6-0004-SM-5DWSG': 'Whole Blood',
#  'GTEX-11EI6-0004-SM-6WBTC': 'Whole Blood',
#  'GTEX-11EI6-0004-SM-7FG6D': 'Whole Blood',
#  'GTEX-11EI6-0005-SM-5N9GN': 'Whole Blood',
#  'GTEX-11EI6-0008-SM-5QGR7': 'Cells - Cultured fibroblasts',
#  'GTEX-11EI6-0011-R10a-SM-CYKQP': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11EI6-0011-R10a-SM-DO93R': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11EI6-0011-R11a-SM-DO11V': 'Brain - Cerebellar Hemisphere',
#  'GTEX-11EI6-0011-R1a-SM-DO93L': 'Brain - Hippocampus',
#  'GTEX-11EI6-0011-R8a-SM-DO93M': 'Brain - Hypothalamus',
#  'GTEX-11EI6-0126-SM-5985R': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11EI6-0226-SM-5EQ64': 'Adipose - Subcutaneous',
#  'GTEX-11EI6-0326-SM-5EQ6G': 'Muscle - Skeletal',
#  'GTEX-11EI6-0426-SM-5EQ43': 'Nerve - Tibial',
#  'GTEX-11EI6-0526-SM-5985S': 'Artery - Tibial',
#  'GTEX-11EI6-0626-SM-5985T': 'Breast - Mammary Tissue',
#  'GTEX-11EI6-0726-SM-59866': 'Thyroid',
#  'GTEX-11EI6-0826-SM-5985V': 'Lung',
#  'GTEX-11EI6-0826-SM-CYKV8': 'Lung',
#  'GTEX-11EI6-1526-SM-5P9GL': 'Esophagus - Mucosa',
#  'GTEX-11EI6-2226-SM-5EGJM': 'Testis',
#  'GTEX-11EI6-2426-SM-5PNVS': 'Stomach',
#  'GTEX-11EI6-2626-SM-5PNVT': 'Colon - Sigmoid',
#  'GTEX-11EI6-2826-SM-5H11D': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11EI6-2926-SM-5985U': 'Brain - Cerebellum',
#  'GTEX-11EI6-3026-SM-5GZZO': 'Brain - Cortex',
#  'GTEX-11EI6-3126-SM-5H111': 'Pituitary',
#  'GTEX-11EM3-0001-SM-5Q5BD': 'Cells - EBV-transformed lymphocytes',
#  'GTEX-11EM3-0004-SM-58Q9C': 'Whole Blood',
#  'GTEX-11EM3-0004-SM-5DWTY': 'Whole Blood',
#  'GTEX-11EM3-0004-SM-6WBUK': 'Whole Blood',
#  'GTEX-11EM3-0005-SM-5N9DK': 'Whole Blood',
#  'GTEX-11EM3-0126-SM-5985K': 'Thyroid',
#  'GTEX-11EM3-0226-SM-5985Y': 'Artery - Aorta',
#  'GTEX-11EM3-0326-SM-5A5KJ': 'Adrenal Gland',
#  'GTEX-11EM3-0426-SM-5N9BZ': 'Heart - Atrial Appendage',
#  'GTEX-11EM3-0526-SM-5H12N': 'Artery - Coronary',
#  'GTEX-11EM3-0626-SM-5H12Z': 'Heart - Left Ventricle',
#  'GTEX-11EM3-0726-SM-5GZZM': 'Esophagus - Muscularis',
#  'GTEX-11EM3-0826-SM-5N9CC': 'Esophagus - Mucosa',
#  'GTEX-11EM3-0926-SM-5A5KK': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11EM3-1026-SM-5A5KL': 'Stomach',
#  'GTEX-11EM3-1126-SM-5A5KM': 'Adipose - Visceral (Omentum)',
#  'GTEX-11EM3-1226-SM-5N9DD': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11EM3-1326-SM-5N9C6': 'Breast - Mammary Tissue',
#  'GTEX-11EM3-1526-SM-5A5KN': 'Colon - Transverse',
#  'GTEX-11EM3-1626-SM-5N9CO': 'Colon - Sigmoid',
#  'GTEX-11EM3-1726-SM-5N9D1': 'Ovary',
#  'GTEX-11EM3-1826-SM-5A5KO': 'Vagina',
#  'GTEX-11EM3-1926-SM-5987U': 'Uterus',
#  'GTEX-11EM3-2126-SM-5H11M': 'Muscle - Skeletal',
#  'GTEX-11EM3-2226-SM-5H11Y': 'Artery - Tibial',
#  'GTEX-11EM3-2326-SM-5H12B': 'Adipose - Subcutaneous',
#  'GTEX-11EM3-2426-SM-59861': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11EMC-0002-SM-5Q5DO': 'Cells - EBV-transformed lymphocytes',
#  'GTEX-11EMC-0004-SM-58Q8T': 'Whole Blood',
#  'GTEX-11EMC-0004-SM-5DWTM': 'Whole Blood',
#  'GTEX-11EMC-0004-SM-6WBUA': 'Whole Blood',
#  'GTEX-11EMC-0006-SM-5O9DN': 'Whole Blood',
#  'GTEX-11EMC-0008-SM-5Q5DR': 'Cells - Cultured fibroblasts',
#  'GTEX-11EMC-0011-R10a-SM-DNZZJ': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11EMC-0011-R11b-SM-DNZZK': 'Brain - Cerebellar Hemisphere',
#  'GTEX-11EMC-0011-R2b-SM-DO114': 'Brain - Substantia nigra',
#  'GTEX-11EMC-0011-R8b-SM-DO91Z': 'Brain - Hypothalamus',
#  'GTEX-11EMC-0011-R9b-SM-DO921': 'Brain - Spinal cord (cervical c-1)',
#  'GTEX-11EMC-0126-SM-5EGKV': 'Lung',
#  'GTEX-11EMC-0226-SM-5EGLP': 'Thyroid',
#  'GTEX-11EMC-0526-SM-5EGJN': 'Adrenal Gland',
#  'GTEX-11EMC-0726-SM-5EGJO': 'Heart - Left Ventricle',
#  'GTEX-11EMC-0826-SM-59862': 'Heart - Atrial Appendage',
#  'GTEX-11EMC-0926-SM-59863': 'Artery - Aorta',
#  'GTEX-11EMC-1426-SM-5N9E4': 'Colon - Sigmoid',
#  'GTEX-11EMC-1726-SM-5H11P': 'Ovary',
#  'GTEX-11EMC-1826-SM-5A5JT': 'Uterus',
#  'GTEX-11EMC-1926-SM-5A5JU': 'Vagina',
#  'GTEX-11EMC-2026-SM-5A5JV': 'Breast - Mammary Tissue',
#  'GTEX-11EMC-2226-SM-5A5JW': 'Esophagus - Mucosa',
#  'GTEX-11EMC-2526-SM-5PNVU': 'Minor Salivary Gland',
#  'GTEX-11EMC-2626-SM-59864': 'Muscle - Skeletal',
#  'GTEX-11EMC-2826-SM-5PNY6': 'Adipose - Subcutaneous',
#  'GTEX-11EMC-2926-SM-5EQ4F': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11EMC-3026-SM-5EQ4R': 'Artery - Tibial',
#  'GTEX-11EMC-3126-SM-5EGJP': 'Pituitary',
#  'GTEX-11EMC-3226-SM-5EGKW': 'Brain - Cortex',
#  'GTEX-11EMC-3326-SM-5P9JH': 'Brain - Cerebellum',
#  'GTEX-11EQ8-0001-SM-58Q82': 'Whole Blood',
#  'GTEX-11EQ8-0001-SM-5DWSU': 'Whole Blood',
#  'GTEX-11EQ8-0001-SM-6WBTP': 'Whole Blood',
#  'GTEX-11EQ8-0006-SM-5P9HJ': 'Whole Blood',
#  'GTEX-11EQ8-0008-SM-5Q5DJ': 'Cells - Cultured fibroblasts',
#  'GTEX-11EQ8-0126-SM-5EQ54': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11EQ8-0226-SM-5EQ5G': 'Adipose - Subcutaneous',
#  'GTEX-11EQ8-0426-SM-5N9DP': 'Artery - Tibial',
#  'GTEX-11EQ8-0526-SM-5N9BC': 'Muscle - Skeletal',
#  'GTEX-11EQ8-0826-SM-5N9FG': 'Thyroid',
#  'GTEX-11EQ8-0926-SM-5H12V': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11EQ8-1326-SM-5EGJQ': 'Heart - Atrial Appendage',
#  'GTEX-11EQ8-1426-SM-5EGJR': 'Testis',
#  'GTEX-11EQ8-2626-SM-5N9BO': 'Colon - Sigmoid',
#  'GTEX-11EQ8-2826-SM-5N9C1': 'Brain - Cerebellum',
#  'GTEX-11EQ9-0002-SM-5QGQ1': 'Cells - EBV-transformed lymphocytes',
#  'GTEX-11EQ9-0003-SM-58Q7V': 'Whole Blood',
#  'GTEX-11EQ9-0003-SM-5DWSP': 'Whole Blood',
#  'GTEX-11EQ9-0003-SM-6WBTK': 'Whole Blood',
#  'GTEX-11EQ9-0006-SM-5LUB6': 'Whole Blood',
#  'GTEX-11EQ9-0008-SM-5Q5DK': 'Cells - Cultured fibroblasts',
#  'GTEX-11EQ9-0126-SM-5986I': 'Adrenal Gland',
#  'GTEX-11EQ9-0226-SM-5A5JX': 'Lung',
#  'GTEX-11EQ9-0426-SM-5A5JY': 'Spleen',
#  'GTEX-11EQ9-0526-SM-5A5JZ': 'Liver',
#  'GTEX-11EQ9-0626-SM-5A5K1': 'Thyroid',
#  'GTEX-11EQ9-0726-SM-5A5K2': 'Esophagus - Mucosa',
#  'GTEX-11EQ9-0826-SM-5986Y': 'Esophagus - Muscularis',
#  'GTEX-11EQ9-0926-SM-5HL6I': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11EQ9-1026-SM-5H134': 'Pancreas',
#  'GTEX-11EQ9-1126-SM-5987I': 'Adipose - Visceral (Omentum)',
#  'GTEX-11EQ9-1226-SM-5987E': 'Stomach',
#  'GTEX-11EQ9-1326-SM-5985X': 'Small Intestine - Terminal Ileum',
#  'GTEX-11EQ9-1426-SM-5987G': 'Colon - Transverse',
#  'GTEX-11EQ9-1526-SM-5PNY7': 'Colon - Sigmoid',
#  'GTEX-11EQ9-1626-SM-5PNY8': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11EQ9-1726-SM-5HL6U': 'Prostate',
#  'GTEX-11EQ9-1826-SM-5Q5AJ': 'Breast - Mammary Tissue',
#  'GTEX-11EQ9-1926-SM-5PNVV': 'Testis',
#  'GTEX-11EQ9-2026-SM-5P9JI': 'Minor Salivary Gland',
#  'GTEX-11EQ9-2126-SM-5PNVW': 'Muscle - Skeletal',
#  'GTEX-11EQ9-2226-SM-5987H': 'Artery - Tibial',
#  'GTEX-11EQ9-2326-SM-5HL5H': 'Nerve - Tibial',
#  'GTEX-11EQ9-2426-SM-5HL5T': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11EQ9-2526-SM-5HL66': 'Adipose - Subcutaneous',
#  'GTEX-11GS4-0004-SM-58Q7W': 'Whole Blood',
#  'GTEX-11GS4-0004-SM-5DWSQ': 'Whole Blood',
#  'GTEX-11GS4-0004-SM-6WBTL': 'Whole Blood',
#  'GTEX-11GS4-0006-SM-5SI9M': 'Whole Blood',
#  'GTEX-11GS4-0008-SM-5QGRA': 'Cells - Cultured fibroblasts',
#  'GTEX-11GS4-0011-R10a-SM-AHZ7I': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11GS4-0011-R1a-SM-DO129': 'Brain - Hippocampus',
#  'GTEX-11GS4-0011-R2a-SM-DO942': 'Brain - Substantia nigra',
#  'GTEX-11GS4-0226-SM-5HL77': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11GS4-0326-SM-5N9F7': 'Artery - Aorta',
#  'GTEX-11GS4-0426-SM-5N9CD': 'Heart - Atrial Appendage',
#  'GTEX-11GS4-0526-SM-5A5KQ': 'Heart - Left Ventricle',
#  'GTEX-11GS4-0626-SM-5A5LC': 'Artery - Coronary',
#  'GTEX-11GS4-0826-SM-5986J': 'Thyroid',
#  'GTEX-11GS4-1026-SM-5N9DE': 'Adipose - Visceral (Omentum)',
#  'GTEX-11GS4-1426-SM-5N9D2': 'Esophagus - Muscularis',
#  'GTEX-11GS4-1826-SM-5HL4T': 'Colon - Sigmoid',
#  'GTEX-11GS4-2026-SM-5N9CP': 'Testis',
#  'GTEX-11GS4-2126-SM-5A5KR': 'Breast - Mammary Tissue',
#  'GTEX-11GS4-2326-SM-5A5KS': 'Kidney - Cortex',
#  'GTEX-11GS4-2526-SM-5A5KT': 'Muscle - Skeletal',
#  'GTEX-11GS4-2526-SM-CYKV3': 'Muscle - Skeletal',
#  'GTEX-11GS4-2626-SM-5A5LD': 'Adipose - Subcutaneous',
#  'GTEX-11GS4-2726-SM-5A5LE': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11GS4-2826-SM-5HL56': 'Nerve - Tibial',
#  'GTEX-11GS4-2926-SM-5A5LF': 'Artery - Tibial',
#  'GTEX-11GS4-3026-SM-5A5LG': 'Pituitary',
#  'GTEX-11GS4-3126-SM-5A5LH': 'Brain - Cortex',
#  'GTEX-11GSO-0003-SM-58Q84': 'Whole Blood',
#  'GTEX-11GSO-0003-SM-5DWSW': 'Whole Blood',
#  'GTEX-11GSO-0003-SM-6WBTR': 'Whole Blood',
#  'GTEX-11GSO-0005-SM-5O9CA': 'Whole Blood',
#  'GTEX-11GSO-0011-R10a-SM-AHZ7H': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11GSO-0011-R1b-SM-57WD3': 'Brain - Hippocampus',
#  'GTEX-11GSO-0011-R2a-SM-57WDF': 'Brain - Substantia nigra',
#  'GTEX-11GSO-0011-R3b-SM-57WB2': 'Brain - Anterior cingulate cortex (BA24)',
#  'GTEX-11GSO-0226-SM-5A5LV': 'Adipose - Visceral (Omentum)',
#  'GTEX-11GSO-0626-SM-5A5LW': 'Thyroid',
#  'GTEX-11GSO-1926-SM-5A5K3': 'Breast - Mammary Tissue',
#  'GTEX-11GSO-2326-SM-5A5LX': 'Adipose - Subcutaneous',
#  'GTEX-11GSO-2426-SM-5A5LY': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11GSO-2526-SM-5PNVX': 'Muscle - Skeletal',
#  'GTEX-11GSO-2526-SM-CYKO1': 'Muscle - Skeletal',
#  'GTEX-11GSO-2626-SM-5Q5AK': 'Nerve - Tibial',
#  'GTEX-11GSO-2826-SM-5HL6Q': 'Pituitary',
#  'GTEX-11GSO-2926-SM-5HL73': 'Brain - Cortex',
#  'GTEX-11GSO-2926-SM-CYKQT': 'Brain - Cortex',
#  'GTEX-11GSO-3026-SM-5Q5AL': 'Brain - Cerebellum',
#  'GTEX-11GSP-0004-SM-58Q83': 'Whole Blood',
#  'GTEX-11GSP-0004-SM-5DWSV': 'Whole Blood',
#  'GTEX-11GSP-0004-SM-6WBTQ': 'Whole Blood',
#  'GTEX-11GSP-0006-SM-5N9EL': 'Whole Blood',
#  'GTEX-11GSP-0008-SM-5Q5DM': 'Cells - Cultured fibroblasts',
#  'GTEX-11GSP-0011-R10a-SM-5NQ7J': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11GSP-0011-R11b-SM-5NQ7V': 'Brain - Cerebellar Hemisphere',
#  'GTEX-11GSP-0011-R1a-SM-9QEJ3': 'Brain - Hippocampus',
#  'GTEX-11GSP-0011-R2b-SM-9QEGE': 'Brain - Substantia nigra',
#  'GTEX-11GSP-0011-R3a-SM-9QEGF': 'Brain - Anterior cingulate cortex (BA24)',
#  'GTEX-11GSP-0011-R5a-SM-57WBE': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11GSP-0011-R6b-SM-57WBQ': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-11GSP-0011-R7b-SM-57WC3': 'Brain - Putamen (basal ganglia)',
#  'GTEX-11GSP-0011-R8b-SM-5NQ79': 'Brain - Hypothalamus',
#  'GTEX-11GSP-0011-R9b-SM-5NQ77': 'Brain - Spinal cord (cervical c-1)',
#  'GTEX-11GSP-0126-SM-5A5KU': 'Thyroid',
#  'GTEX-11GSP-0226-SM-5A5KV': 'Ovary',
#  'GTEX-11GSP-0326-SM-5A5KW': 'Adrenal Gland',
#  'GTEX-11GSP-0426-SM-5A5KX': 'Pancreas',
#  'GTEX-11GSP-0626-SM-5986T': 'Liver',
#  'GTEX-11GSP-0726-SM-5986L': 'Lung',
#  'GTEX-11GSP-0926-SM-9WYSG': 'Breast - Mammary Tissue',
#  'GTEX-11GSP-1026-SM-9WYSH': 'Adipose - Visceral (Omentum)',
#  'GTEX-11GSP-1126-SM-5A5LM': 'Artery - Aorta',
#  'GTEX-11GSP-1226-SM-5985M': 'Heart - Atrial Appendage',
#  'GTEX-11GSP-1326-SM-5A5KY': 'Heart - Left Ventricle',
#  'GTEX-11GSP-1626-SM-5986N': 'Colon - Transverse',
#  'GTEX-11GSP-1726-SM-5A5LI': 'Esophagus - Muscularis',
#  'GTEX-11GSP-1826-SM-5N9DQ': 'Esophagus - Mucosa',
#  'GTEX-11GSP-2126-SM-5HL5E': 'Stomach',
#  'GTEX-11GSP-2226-SM-5HL5Q': 'Vagina',
#  'GTEX-11GSP-2326-SM-5HL63': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11GSP-2426-SM-5N9BD': 'Uterus',
#  'GTEX-11GSP-2526-SM-5N9BP': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11GSP-2726-SM-5A5LJ': 'Muscle - Skeletal',
#  'GTEX-11GSP-2826-SM-5A5LK': 'Nerve - Tibial',
#  'GTEX-11GSP-2926-SM-5N9C2': 'Artery - Tibial',
#  'GTEX-11GSP-3026-SM-5N9CE': 'Pituitary',
#  'GTEX-11GSP-3126-SM-5A5LL': 'Brain - Cerebellum',
#  'GTEX-11GSP-3226-SM-5986O': 'Brain - Cortex',
#  'GTEX-11H98-0008-SM-5QGR8': 'Cells - Cultured fibroblasts',
#  'GTEX-11H98-0011-R10b-SM-5NQ98': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11H98-0011-R11b-SM-5NQ6U': 'Brain - Cerebellar Hemisphere',
#  'GTEX-11H98-0011-R5b-SM-57WCF': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11H98-0011-R8a-SM-5NQ8V': 'Brain - Hypothalamus',
#  'GTEX-11H98-0126-SM-5EGHG': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11H98-0226-SM-5NQ89': 'Adipose - Subcutaneous',
#  'GTEX-11H98-0326-SM-5HL4S': 'Muscle - Skeletal',
#  'GTEX-11H98-0426-SM-5HL55': 'Nerve - Tibial',
#  'GTEX-11H98-0426-SM-EZ6XS': 'Nerve - Tibial',
#  'GTEX-11I78-0001-SM-5Q5BE': 'Cells - EBV-transformed lymphocytes',
#  'GTEX-11I78-0002-SM-58Q8G': 'Whole Blood',
#  'GTEX-11I78-0002-SM-5DWT9': 'Whole Blood',
#  'GTEX-11I78-0002-SM-6WBU2': 'Whole Blood',
#  'GTEX-11I78-0005-SM-5N9GB': 'Whole Blood',
#  'GTEX-11I78-0008-SM-5Q5DI': 'Cells - Cultured fibroblasts',
#  'GTEX-11I78-0126-SM-5HL6F': 'Lung',
#  'GTEX-11I78-0226-SM-5HL6R': 'Adipose - Visceral (Omentum)',
#  'GTEX-11I78-0526-SM-5986A': 'Thyroid',
#  'GTEX-11I78-0626-SM-5A5LZ': 'Pancreas',
#  'GTEX-11I78-0726-SM-5A5M1': 'Artery - Aorta',
#  'GTEX-11I78-0826-SM-5A5K4': 'Heart - Left Ventricle',
#  'GTEX-11I78-1026-SM-5HL74': 'Artery - Coronary',
#  'GTEX-11I78-1126-SM-5A5K5': 'Small Intestine - Terminal Ileum',
#  'GTEX-11I78-1226-SM-5A5K6': 'Colon - Transverse',
#  'GTEX-11I78-1326-SM-5PNY9': 'Colon - Sigmoid',
#  'GTEX-11I78-1426-SM-5PNVY': 'Esophagus - Muscularis',
#  'GTEX-11I78-1526-SM-5A5K7': 'Esophagus - Mucosa',
#  'GTEX-11I78-1626-SM-5A5M2': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11I78-1726-SM-5A5M3': 'Stomach',
#  'GTEX-11I78-1826-SM-5A5M4': 'Adrenal Gland',
#  'GTEX-11I78-1926-SM-59878': 'Ovary',
#  'GTEX-11I78-2026-SM-5987C': 'Vagina',
#  'GTEX-11I78-2126-SM-5A5K8': 'Uterus',
#  'GTEX-11I78-2226-SM-5PNYA': 'Breast - Mammary Tissue',
#  'GTEX-11I78-2326-SM-5Q5AH': 'Artery - Tibial',
#  'GTEX-11I78-2426-SM-5A5K9': 'Muscle - Skeletal',
#  'GTEX-11I78-2626-SM-5Q5AI': 'Adipose - Subcutaneous',
#  'GTEX-11ILO-0002-SM-5CV9V': 'Whole Blood',
#  'GTEX-11ILO-0006-SM-5LZWE': 'Whole Blood',
#  'GTEX-11ILO-0008-SM-5QGR9': 'Cells - Cultured fibroblasts',
#  'GTEX-11ILO-0126-SM-5A5LN': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11ILO-0226-SM-5N9D3': 'Adipose - Subcutaneous',
#  'GTEX-11ILO-0426-SM-5HL4V': 'Nerve - Tibial',
#  'GTEX-11ILO-0526-SM-5N9DF': 'Artery - Tibial',
#  'GTEX-11ILO-0626-SM-5A5LO': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11ILO-0726-SM-5HL5I': 'Lung',
#  'GTEX-11ILO-1026-SM-5A5LP': 'Esophagus - Mucosa',
#  'GTEX-11ILO-1526-SM-5A5KZ': 'Pancreas',
#  'GTEX-11ILO-2026-SM-5N9CQ': 'Colon - Transverse',
#  'GTEX-11ILO-2226-SM-5A5L1': 'Breast - Mammary Tissue',
#  'GTEX-11ILO-2526-SM-5A5LQ': 'Heart - Atrial Appendage',
#  'GTEX-11ILO-2626-SM-DLIPH': 'Thyroid',
#  'GTEX-11LCK-0002-SM-58Q7P': 'Whole Blood',
#  'GTEX-11LCK-0002-SM-5DWRA': 'Whole Blood',
#  'GTEX-11LCK-0002-SM-6WBSW': 'Whole Blood',
#  'GTEX-11LCK-0005-SM-5O98U': 'Whole Blood',
#  'GTEX-11LCK-0008-SM-5Q5BB': 'Cells - Cultured fibroblasts',
#  'GTEX-11LCK-0126-SM-5A5M5': 'Spleen',
#  'GTEX-11LCK-0226-SM-5A5M6': 'Pancreas',
#  'GTEX-11LCK-0326-SM-5A5M7': 'Adipose - Visceral (Omentum)',
#  'GTEX-11LCK-0426-SM-5A5M8': 'Lung',
#  'GTEX-11LCK-0526-SM-5A5M9': 'Thyroid',
#  'GTEX-11LCK-0726-SM-5PNYC': 'Artery - Aorta',
#  'GTEX-11LCK-0826-SM-5PNYD': 'Heart - Atrial Appendage',
#  'GTEX-11LCK-0926-SM-5A5KA': 'Heart - Left Ventricle',
#  'GTEX-11LCK-1026-SM-5A5KB': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11LCK-1126-SM-5A5KC': 'Adipose - Subcutaneous',
#  'GTEX-11LCK-1226-SM-5Q5AM': 'Muscle - Skeletal',
#  'GTEX-11LCK-1326-SM-5Q5AN': 'Nerve - Tibial',
#  'GTEX-11LCK-1426-SM-5HL5R': 'Artery - Tibial',
#  'GTEX-11LCK-1526-SM-5HL64': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11LCK-1626-SM-5PNYB': 'Esophagus - Muscularis',
#  'GTEX-11LCK-1726-SM-5S2OQ': 'Esophagus - Mucosa',
#  'GTEX-11LCK-1926-SM-5A5KE': 'Small Intestine - Terminal Ileum',
#  'GTEX-11LCK-2026-SM-5A5MA': 'Colon - Transverse',
#  'GTEX-11LCK-2226-SM-5HL4Q': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11LCK-2326-SM-5HL53': 'Testis',
#  'GTEX-11LCK-2426-SM-5HL5F': 'Breast - Mammary Tissue',
#  'GTEX-11NSD-0005-SM-5LZZ5': 'Whole Blood',
#  'GTEX-11NSD-0008-SM-5Q5BC': 'Cells - Cultured fibroblasts',
#  'GTEX-11NSD-0126-SM-5987F': 'Thyroid',
#  'GTEX-11NSD-0126-SM-DLIPG': 'Thyroid',
#  'GTEX-11NSD-0126-SM-DMZ2Z': 'Thyroid',
#  'GTEX-11NSD-0226-SM-5A5LR': 'Adrenal Gland',
#  'GTEX-11NSD-0326-SM-5A5LS': 'Lung',
#  'GTEX-11NSD-0426-SM-5N9CR': 'Spleen',
#  'GTEX-11NSD-0526-SM-5A5LT': 'Pancreas',
#  'GTEX-11NSD-0626-SM-5A5LU': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11NSD-0826-SM-5986S': 'Prostate',
#  'GTEX-11NSD-0926-SM-5N9DR': 'Breast - Mammary Tissue',
#  'GTEX-11NSD-1026-SM-5N9BE': 'Testis',
#  'GTEX-11NSD-1126-SM-5N9BQ': 'Esophagus - Mucosa',
#  'GTEX-11NSD-1226-SM-5986Q': 'Esophagus - Muscularis',
#  'GTEX-11NSD-1426-SM-5HL67': 'Stomach',
#  'GTEX-11NSD-1626-SM-5986U': 'Colon - Transverse',
#  'GTEX-11NSD-1726-SM-5N9C3': 'Small Intestine - Terminal Ileum',
#  'GTEX-11NSD-1826-SM-5N9CF': 'Nerve - Tibial',
#  'GTEX-11NSD-2026-SM-5HL5U': 'Muscle - Skeletal',
#  'GTEX-11NSD-2226-SM-5986V': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11NUK-0004-SM-58Q87': 'Whole Blood',
#  'GTEX-11NUK-0004-SM-5DWSZ': 'Whole Blood',
#  'GTEX-11NUK-0004-SM-6WBTU': 'Whole Blood',
#  'GTEX-11NUK-0005-SM-5MR5F': 'Whole Blood',
#  'GTEX-11NUK-0008-SM-5Q5B9': 'Cells - Cultured fibroblasts',
#  'GTEX-11NUK-0011-R4a-SM-DO12B': 'Brain - Amygdala',
#  'GTEX-11NUK-0011-R5a-SM-DO93N': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11NUK-0011-R6a-SM-DO93O': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-11NUK-0011-R7a-SM-DO93P': 'Brain - Putamen (basal ganglia)',
#  'GTEX-11NUK-0126-SM-5A5L3': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11NUK-0226-SM-5A5L4': 'Muscle - Skeletal',
#  'GTEX-11NUK-0326-SM-5HL5K': 'Adipose - Subcutaneous',
#  'GTEX-11NUK-0426-SM-5HL5V': 'Nerve - Tibial',
#  'GTEX-11NUK-0526-SM-5A5L5': 'Artery - Tibial',
#  'GTEX-11NUK-0726-SM-5A5ME': 'Artery - Aorta',
#  'GTEX-11NUK-0826-SM-5HL4U': 'Lung',
#  'GTEX-11NUK-0926-SM-5HL57': 'Heart - Atrial Appendage',
#  'GTEX-11NUK-1026-SM-5HL5J': 'Thyroid',
#  'GTEX-11NUK-1226-SM-5P9GM': 'Liver',
#  'GTEX-11NUK-1326-SM-5P9GN': 'Esophagus - Mucosa',
#  'GTEX-11NUK-1426-SM-5HL68': 'Esophagus - Muscularis',
#  'GTEX-11NUK-1726-SM-5A5L2': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11NUK-2026-SM-5PNVZ': 'Adipose - Visceral (Omentum)',
#  'GTEX-11NUK-2426-SM-5BC4U': 'Stomach',
#  'GTEX-11NUK-2626-SM-5A5MB': 'Testis',
#  'GTEX-11NUK-2726-SM-5A5MC': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11NUK-2926-SM-5A5MD': 'Brain - Cortex',
#  'GTEX-11NUK-3026-SM-5986K': 'Brain - Cerebellum',
#  'GTEX-11NUK-3126-SM-5986M': 'Pituitary',
#  'GTEX-11NV4-0001-SM-58Q86': 'Whole Blood',
#  'GTEX-11NV4-0001-SM-5DWSY': 'Whole Blood',
#  'GTEX-11NV4-0001-SM-6WBTT': 'Whole Blood',
#  'GTEX-11NV4-0005-SM-5N9EX': 'Whole Blood',
#  'GTEX-11NV4-0008-SM-5Q5BA': 'Cells - Cultured fibroblasts',
#  'GTEX-11NV4-0011-R5a-SM-5NQ88': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11NV4-0011-R6a-SM-57WD5': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-11NV4-0011-R7a-SM-57WDH': 'Brain - Putamen (basal ganglia)',
#  'GTEX-11NV4-0326-SM-5HL58': 'Muscle - Skeletal',
#  'GTEX-11NV4-0526-SM-5N9BF': 'Artery - Tibial',
#  'GTEX-11NV4-0626-SM-5N9BR': 'Thyroid',
#  'GTEX-11NV4-0826-SM-5BC4S': 'Heart - Atrial Appendage',
#  'GTEX-11NV4-1126-SM-5HL6J': 'Lung',
#  'GTEX-11NV4-1326-SM-5HL6V': 'Liver',
#  'GTEX-11NV4-1426-SM-5BC4W': 'Adipose - Visceral (Omentum)',
#  'GTEX-11NV4-1726-SM-5N9FC': 'Testis',
#  'GTEX-11NV4-1926-SM-5N9D4': 'Minor Salivary Gland',
#  'GTEX-11NV4-2026-SM-5N9DG': 'Breast - Mammary Tissue',
#  'GTEX-11NV4-2126-SM-5N9DS': 'Brain - Cortex',
#  'GTEX-11NV4-2226-SM-5BC4T': 'Brain - Cerebellum',
#  'GTEX-11NV4-2326-SM-5BC4X': 'Pituitary',
#  'GTEX-11O72-0006-SM-5O9DB': 'Whole Blood',
#  'GTEX-11O72-0008-SM-5Q5DN': 'Cells - Cultured fibroblasts',
#  'GTEX-11O72-0011-R5a-SM-DO922': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11O72-0011-R6a-SM-DNZZQ': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-11O72-0126-SM-59887': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11O72-0226-SM-59869': 'Adipose - Subcutaneous',
#  'GTEX-11O72-0326-SM-5986D': 'Muscle - Skeletal',
#  'GTEX-11O72-0426-SM-5BC5B': 'Artery - Tibial',
#  'GTEX-11O72-0526-SM-5Q5AO': 'Nerve - Tibial',
#  'GTEX-11O72-0626-SM-5PNYE': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11O72-0726-SM-5P9GO': 'Testis',
#  'GTEX-11O72-1026-SM-5986B': 'Heart - Atrial Appendage',
#  'GTEX-11O72-1126-SM-5N9E2': 'Heart - Left Ventricle',
#  'GTEX-11O72-1326-SM-5BC5A': 'Lung',
#  'GTEX-11O72-1726-SM-DLIP2': 'Kidney - Cortex',
#  'GTEX-11O72-1726-SM-DMZ2Y': 'Kidney - Cortex',
#  'GTEX-11O72-1926-SM-5PNW1': 'Esophagus - Muscularis',
#  'GTEX-11O72-2026-SM-5N9G8': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11O72-2126-SM-5N9FO': 'Breast - Mammary Tissue',
#  'GTEX-11O72-2226-SM-5PNW2': 'Colon - Transverse',
#  'GTEX-11O72-2326-SM-5BC7H': 'Thyroid',
#  'GTEX-11O72-2726-SM-5HL6K': 'Prostate',
#  'GTEX-11O72-2826-SM-5HL6W': 'Brain - Cerebellum',
#  'GTEX-11O72-2926-SM-5BC4V': 'Brain - Cortex',
#  'GTEX-11O72-3026-SM-5986R': 'Pituitary',
#  'GTEX-11OC5-0004-SM-5S2O6': 'Cells - EBV-transformed lymphocytes',
#  'GTEX-11OC5-0006-SM-5N9FA': 'Whole Blood',
#  'GTEX-11OC5-0008-SM-5S2OH': 'Cells - Cultured fibroblasts',
#  'GTEX-11OC5-0126-SM-5HL6A': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11OC5-0326-SM-5PNW5': 'Muscle - Skeletal',
#  'GTEX-11OC5-0426-SM-5Q5AR': 'Artery - Tibial',
#  'GTEX-11OC5-0526-SM-5N9EE': 'Nerve - Tibial',
#  'GTEX-11OC5-0526-SM-EZ6XW': 'Nerve - Tibial',
#  'GTEX-11OC5-0626-SM-5HL6M': 'Brain - Cerebellum',
#  'GTEX-11OC5-0726-SM-5P9JK': 'Brain - Cortex',
#  'GTEX-11OF3-0006-SM-5O9CM': 'Whole Blood',
#  'GTEX-11OF3-0008-SM-5S2NH': 'Cells - Cultured fibroblasts',
#  'GTEX-11OF3-0011-R11a-SM-57WCR': 'Brain - Cerebellar Hemisphere',
#  'GTEX-11OF3-0011-R5a-SM-57WB4': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11OF3-0011-R6b-SM-57WBG': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-11OF3-0011-R7a-SM-57WCG': 'Brain - Putamen (basal ganglia)',
#  'GTEX-11OF3-0011-R8b-SM-57WCS': 'Brain - Hypothalamus',
#  'GTEX-11OF3-0126-SM-5PNYF': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11OF3-0626-SM-5BC4Y': 'Thyroid',
#  'GTEX-11OF3-0726-SM-5BC4Z': 'Liver',
#  'GTEX-11OF3-0826-SM-5BC51': 'Adipose - Visceral (Omentum)',
#  'GTEX-11OF3-1126-SM-5986C': 'Lung',
#  'GTEX-11OF3-1326-SM-5N9FJ': 'Kidney - Cortex',
#  'GTEX-11OF3-1326-SM-DLIPK': 'Kidney - Cortex',
#  'GTEX-11OF3-1326-SM-DMZ32': 'Kidney - Cortex',
#  'GTEX-11OF3-1726-SM-5GU5Q': 'Prostate',
#  'GTEX-11OF3-1826-SM-5987N': 'Testis',
#  'GTEX-11OF3-1926-SM-59889': 'Breast - Mammary Tissue',
#  'GTEX-11OF3-2226-SM-5986F': 'Esophagus - Muscularis',
#  'GTEX-11OF3-2326-SM-5GU73': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11OF3-2426-SM-5Q5AS': 'Adipose - Subcutaneous',
#  'GTEX-11OF3-2526-SM-5P9JL': 'Muscle - Skeletal',
#  'GTEX-11OF3-2626-SM-5GU7F': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11OF3-2926-SM-5HL78': 'Brain - Cortex',
#  'GTEX-11OF3-3026-SM-5GU52': 'Pituitary',
#  'GTEX-11OF3-3126-SM-5GU5E': 'Brain - Cerebellum',
#  'GTEX-11ONC-0003-SM-5DWT5': 'Whole Blood',
#  'GTEX-11ONC-0005-SM-5O9CY': 'Whole Blood',
#  'GTEX-11ONC-0008-SM-5S2MG': 'Cells - Cultured fibroblasts',
#  'GTEX-11ONC-0011-R1a-SM-57WD4': 'Brain - Hippocampus',
#  'GTEX-11ONC-0011-R4b-SM-DO93H': 'Brain - Amygdala',
#  'GTEX-11ONC-0011-R5b-SM-DO93I': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11ONC-0011-R6a-SM-DO12A': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-11ONC-0011-R7b-SM-DO93J': 'Brain - Putamen (basal ganglia)',
#  'GTEX-11ONC-0011-R8b-SM-5NQ87': 'Brain - Hypothalamus',
#  'GTEX-11ONC-0011-R9b-SM-5NQ8J': 'Brain - Spinal cord (cervical c-1)',
#  'GTEX-11ONC-0126-SM-5PNW6': 'Heart - Left Ventricle',
#  'GTEX-11ONC-0526-SM-5BC57': 'Pancreas',
#  'GTEX-11ONC-0926-SM-5BC5E': 'Artery - Aorta',
#  'GTEX-11ONC-1026-SM-5GU64': 'Heart - Atrial Appendage',
#  'GTEX-11ONC-1126-SM-5GU6G': 'Artery - Coronary',
#  'GTEX-11ONC-1326-SM-DLIPJ': 'Kidney - Cortex',
#  'GTEX-11ONC-1426-SM-5N9F4': 'Esophagus - Muscularis',
#  'GTEX-11ONC-1526-SM-5GU6S': 'Esophagus - Mucosa',
#  'GTEX-11ONC-1926-SM-5GU75': 'Colon - Sigmoid',
#  'GTEX-11ONC-2026-SM-5HL61': 'Colon - Transverse',
#  'GTEX-11ONC-2126-SM-5HL6E': 'Breast - Mammary Tissue',
#  'GTEX-11ONC-2226-SM-5HL6D': 'Testis',
#  'GTEX-11ONC-2326-SM-5HL6P': 'Nerve - Tibial',
#  'GTEX-11ONC-2326-SM-DOKK8': 'Nerve - Tibial',
#  'GTEX-11ONC-2426-SM-5GU7H': 'Muscle - Skeletal',
#  'GTEX-11ONC-2526-SM-5986W': 'Adipose - Subcutaneous',
#  'GTEX-11ONC-2726-SM-5N9DZ': 'Artery - Tibial',
#  'GTEX-11ONC-2826-SM-5P9GQ': 'Pituitary',
#  'GTEX-11ONC-2926-SM-5P9JM': 'Brain - Cortex',
#  'GTEX-11ONC-3026-SM-5985W': 'Brain - Cerebellum',
#  'GTEX-11P7K-0002-SM-58Q9D': 'Whole Blood',
#  'GTEX-11P7K-0002-SM-5DWTW': 'Whole Blood',
#  'GTEX-11P7K-0002-SM-6WBUI': 'Whole Blood',
#  'GTEX-11P7K-0003-SM-5S2OU': 'Cells - EBV-transformed lymphocytes',
#  'GTEX-11P7K-0006-SM-5N9FM': 'Whole Blood',
#  'GTEX-11P7K-0008-SM-5S2O5': 'Cells - Cultured fibroblasts',
#  'GTEX-11P7K-0126-SM-5986E': 'Adrenal Gland',
#  'GTEX-11P7K-0226-SM-5986Z': 'Thyroid',
#  'GTEX-11P7K-0326-SM-59871': 'Lung',
#  'GTEX-11P7K-0426-SM-5BC5H': 'Spleen',
#  'GTEX-11P7K-0526-SM-5BC5I': 'Pancreas',
#  'GTEX-11P7K-0626-SM-5985Z': 'Prostate',
#  'GTEX-11P7K-0726-SM-5EGKX': 'Breast - Mammary Tissue',
#  'GTEX-11P7K-0826-SM-5BC5F': 'Adipose - Visceral (Omentum)',
#  'GTEX-11P7K-1026-SM-5HL6Y': 'Testis',
#  'GTEX-11P7K-1126-SM-5HL4L': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11P7K-1226-SM-5HL4X': 'Esophagus - Muscularis',
#  'GTEX-11P7K-1326-SM-5BC5G': 'Esophagus - Mucosa',
#  'GTEX-11P7K-1426-SM-5EGKY': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11P7K-1526-SM-5EGI7': 'Colon - Transverse',
#  'GTEX-11P7K-1626-SM-5GU63': 'Small Intestine - Terminal Ileum',
#  'GTEX-11P7K-1726-SM-5GU6F': 'Stomach',
#  'GTEX-11P7K-1826-SM-5HL5A': 'Colon - Sigmoid',
#  'GTEX-11P7K-1926-SM-5GU6R': 'Muscle - Skeletal',
#  'GTEX-11P7K-2026-SM-5GU74': 'Adipose - Subcutaneous',
#  'GTEX-11P7K-2126-SM-5GU7G': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11P7K-2226-SM-5GU56': 'Nerve - Tibial',
#  'GTEX-11P7K-2326-SM-5EGKZ': 'Artery - Tibial',
#  'GTEX-11P81-0002-SM-58Q88': 'Whole Blood',
#  'GTEX-11P81-0002-SM-5DWT1': 'Whole Blood',
#  'GTEX-11P81-0002-SM-6WBTV': 'Whole Blood',
#  'GTEX-11P81-0006-SM-5NQ7A': 'Whole Blood',
#  'GTEX-11P81-0008-SM-5S2OT': 'Cells - Cultured fibroblasts',
#  'GTEX-11P81-0126-SM-5HL5Y': 'Thyroid',
#  'GTEX-11P81-0226-SM-5HL5M': 'Lung',
#  'GTEX-11P81-0326-SM-5HL6B': 'Artery - Aorta',
#  'GTEX-11P81-0526-SM-59873': 'Heart - Atrial Appendage',
#  'GTEX-11P81-0726-SM-5PNYH': 'Adipose - Visceral (Omentum)',
#  'GTEX-11P81-0826-SM-5P9GR': 'Esophagus - Mucosa',
#  'GTEX-11P81-0926-SM-59874': 'Esophagus - Muscularis',
#  'GTEX-11P81-1026-SM-5GU54': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11P81-1126-SM-5GU5G': 'Colon - Transverse',
#  'GTEX-11P81-1326-SM-5GU5S': 'Spleen',
#  'GTEX-11P81-1426-SM-5P9JN': 'Colon - Sigmoid',
#  'GTEX-11P81-1526-SM-5P9GS': 'Ovary',
#  'GTEX-11P81-1626-SM-5BC52': 'Uterus',
#  'GTEX-11P81-1926-SM-5BC53': 'Breast - Mammary Tissue',
#  'GTEX-11P81-2026-SM-5P9GT': 'Minor Salivary Gland',
#  'GTEX-11P81-2126-SM-5HL6N': 'Vagina',
#  'GTEX-11P81-2226-SM-5PNYI': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11P81-2326-SM-59875': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11P81-2426-SM-5GU65': 'Adipose - Subcutaneous',
#  'GTEX-11P81-2526-SM-5GU6H': 'Muscle - Skeletal',
#  'GTEX-11P81-2626-SM-5GU6T': 'Nerve - Tibial',
#  'GTEX-11P81-2726-SM-59876': 'Artery - Tibial',
#  'GTEX-11P82-0003-SM-58Q7E': 'Whole Blood',
#  'GTEX-11P82-0003-SM-5DWRC': 'Whole Blood',
#  'GTEX-11P82-0003-SM-6WBSX': 'Whole Blood',
#  'GTEX-11P82-0006-SM-5N9FY': 'Whole Blood',
#  'GTEX-11P82-0008-SM-5S2MS': 'Cells - Cultured fibroblasts',
#  'GTEX-11P82-0126-SM-5HL72': 'Artery - Aorta',
#  'GTEX-11P82-0226-SM-5HL4O': 'Thyroid',
#  'GTEX-11P82-0326-SM-5HL51': 'Adipose - Visceral (Omentum)',
#  'GTEX-11P82-0426-SM-5HL5D': 'Esophagus - Gastroesophageal Junction',
#  'GTEX-11P82-0526-SM-5986P': 'Esophagus - Mucosa',
#  'GTEX-11P82-0626-SM-5PNYK': 'Esophagus - Muscularis',
#  'GTEX-11P82-0726-SM-5PNYL': 'Stomach',
#  'GTEX-11P82-0826-SM-5P9GU': 'Small Intestine - Terminal Ileum',
#  'GTEX-11P82-0926-SM-5986X': 'Minor Salivary Gland',
#  'GTEX-11P82-1026-SM-5BC5J': 'Colon - Transverse',
#  'GTEX-11P82-1126-SM-5BC5K': 'Prostate',
#  'GTEX-11P82-1226-SM-5HL5P': 'Colon - Sigmoid',
#  'GTEX-11P82-1326-SM-5HL62': 'Breast - Mammary Tissue',
#  'GTEX-11P82-1426-SM-5BC5L': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11P82-1426-SM-DTXFY': 'Skin - Not Sun Exposed (Suprapubic)',
#  'GTEX-11P82-1526-SM-5BC5M': 'Testis',
#  'GTEX-11P82-1626-SM-59879': 'Skin - Sun Exposed (Lower leg)',
#  'GTEX-11P82-1726-SM-5Q5AT': 'Adipose - Subcutaneous',
#  'GTEX-11P82-1826-SM-5PNYJ': 'Muscle - Skeletal',
#  'GTEX-11P82-1926-SM-5Q5AU': 'Nerve - Tibial',
#  'GTEX-11PRG-0004-SM-58Q9A': 'Whole Blood',
#  'GTEX-11PRG-0004-SM-5DWRB': 'Whole Blood',
#  'GTEX-11PRG-0004-SM-6WBUN': 'Whole Blood',
#  'GTEX-11PRG-0005-SM-5NQ6X': 'Whole Blood',
#  'GTEX-11PRG-0008-SM-5S2N5': 'Cells - Cultured fibroblasts',
#  'GTEX-11PRG-0011-R10a-SM-AHZML': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11PRG-0011-R10b-SM-CYKQG': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11PRG-0011-R10b-SM-DO93G': 'Brain - Frontal Cortex (BA9)',
#  'GTEX-11PRG-0011-R11b-SM-DNZZY': 'Brain - Cerebellar Hemisphere',
#  'GTEX-11PRG-0011-R2a-SM-69LQ5': 'Brain - Substantia nigra',
#  'GTEX-11PRG-0011-R4a-SM-DNZZR': 'Brain - Amygdala',
#  'GTEX-11PRG-0011-R5b-SM-DNZZS': 'Brain - Caudate (basal ganglia)',
#  'GTEX-11PRG-0011-R6b-SM-DO923': 'Brain - Nucleus accumbens (basal ganglia)',
#  'GTEX-11PRG-0011-R7a-SM-DNZZT': 'Brain - Putamen (basal ganglia)',
#  ...}

# %% [markdown]
# 2. Load and process the headeer from the GTEx gene expression file "~/Data/GTEx/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz"
#
#     - You have code that will open the file and read in the header line
#     - Create a list of tissues corresponding to the column names in the header, one tissue per column name (don't worry about which the column is a sample ID or not since column names that aren't sample IDs will just get a "missing" label)
#     - For each value in the header, see if it appears in the dictionary of sample ID/tissues that you created in step 1
#     - If the value is in your dictionary, add the corresponding tissue name (the value in dictionary for that sample ID key) to your tissue list
#     - If the value is not in your dictionary, add "missing" to the tissue list

# %%
# Because this file is a gzip-compressed file, you will be using the `gzip` library that comes with python
import gzip

expression_fname = "/Users/cmdb/Data/GTEx/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct.gz"

# Open the file using the gzip library
fs = gzip.open(expression_fname)

# The file starts with two lines of information before the header, so these are skipped using 2 calls of `.readline()` without keeping the returned data
_ = fs.readline()
_ = fs.readline()

# Gzipped text files are read in as byte strings, not regular strings, so you will see that `.decode()` is included after `.readline()` to convert the input into a string
header = fs.readline().decode().rstrip().split("\t")

# Make sure to close the file when you are done reading it
fs.close()

# Create a list to hold the tissue names
tissues = []

# Step through each value in the header
for head in header:
    # Check if the value has an entry in the gene_tissue dictionary, adding either the tissue corresponding to that entry or "missing" to your tissues list
    if head in metadata:
        tissues.append(metadata[head])
    else:
        tissues.append('missing')

print(tissues)
# Out:
# ['missing', 'missing', 'Adipose - Subcutaneous', 'Muscle - Skeletal', 'Artery - Tibial', 'Artery - Coronary', 'Heart - Atrial Appendage', 'Adipose - Visceral (Omentum)', 'Uterus', 'Vagina', 'Breast - Mammary Tissue', 'Skin - Not Sun Exposed (Suprapubic)', 'Minor Salivary Gland', 'Brain - Cortex', 'Adrenal Gland', 'Thyroid', 'Lung', 'Spleen', 'Pancreas', 'Esophagus - Muscularis', 'Esophagus - Mucosa', 'Esophagus - Gastroesophageal Junction', 'Stomach', 'Adipose - Visceral (Omentum)', 'Skin - Not Sun Exposed (Suprapubic)', 'Colon - Sigmoid', 'Small Intestine - Terminal Ileum', 'Colon - Transverse', 'Prostate', 'Testis', 'Adipose - Subcutaneous', 'Muscle - Skeletal', 'Nerve - Tibial', 'Skin - Sun Exposed (Lower leg)', 'Adipose - Subcutaneous', 'Muscle - Skeletal', 'Artery - Tibial', 'Nerve - Tibial', 'Heart - Atrial Appendage', 'Heart - Left Ventricle', 'Thyroid', 'Lung', 'Spleen', 'Testis', 'Prostate', 'Skin - Not Sun Exposed (Suprapubic)', 'Minor Salivary Gland', 'Brain - Cortex', 'Brain - Cerebellum', 'Cells - Cultured fibroblasts', 'Heart - Atrial Appendage', 'Thyroid', 'Lung', 'Skin - Not Sun Exposed (Suprapubic)', 'Testis', 'Colon - Transverse', 'Adipose - Subcutaneous', 'Skin - Sun Exposed (Lower leg)', 'Nerve - Tibial', 'Muscle - Skeletal', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Adrenal Gland', 'Heart - Atrial Appendage', 'Heart - Left Ventricle', 'Artery - Aorta', 'Lung', 'Thyroid', 'Esophagus - Gastroesophageal Junction', 'Esophagus - Mucosa', 'Esophagus - Muscularis', 'Stomach', 'Pancreas', 'Adipose - Visceral (Omentum)', 'Small Intestine - Terminal Ileum', 'Skin - Not Sun Exposed (Suprapubic)', 'Colon - Transverse', 'Prostate', 'Colon - Sigmoid', 'Breast - Mammary Tissue', 'Testis', 'Nerve - Tibial', 'Artery - Tibial', 'Muscle - Skeletal', 'Adipose - Subcutaneous', 'Cells - EBV-transformed lymphocytes', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Lung', 'Thyroid', 'Adrenal Gland', 'Artery - Coronary', 'Spleen', 'Heart - Atrial Appendage', 'Pancreas', 'Heart - Left Ventricle', 'Adipose - Visceral (Omentum)', 'Skin - Not Sun Exposed (Suprapubic)', 'Artery - Aorta', 'Breast - Mammary Tissue', 'Small Intestine - Terminal Ileum', 'Colon - Sigmoid', 'Colon - Transverse', 'Esophagus - Muscularis', 'Esophagus - Mucosa', 'Esophagus - Gastroesophageal Junction', 'Stomach', 'Adipose - Subcutaneous', 'Skin - Sun Exposed (Lower leg)', 'Artery - Tibial', 'Muscle - Skeletal', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Thyroid', 'Artery - Aorta', 'Lung', 'Pancreas', 'Adipose - Visceral (Omentum)', 'Colon - Transverse', 'Adipose - Subcutaneous', 'Skin - Sun Exposed (Lower leg)', 'Muscle - Skeletal', 'Artery - Tibial', 'Pituitary', 'Brain - Cortex', 'Brain - Cerebellum', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Skin - Sun Exposed (Lower leg)', 'Adipose - Subcutaneous', 'Artery - Tibial', 'Nerve - Tibial', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Thyroid', 'Adipose - Visceral (Omentum)', 'Esophagus - Muscularis', 'Esophagus - Gastroesophageal Junction', 'Vagina', 'Uterus', 'Skin - Sun Exposed (Lower leg)', 'Muscle - Skeletal', 'Pituitary', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Artery - Aorta', 'Thyroid', 'Heart - Atrial Appendage', 'Breast - Mammary Tissue', 'Testis', 'Colon - Sigmoid', 'Muscle - Skeletal', 'Skin - Sun Exposed (Lower leg)', 'Pituitary', 'Brain - Cortex', 'Brain - Cerebellum', 'Whole Blood', 'Cells - Cultured fibroblasts', 'Thyroid', 'Artery - Aorta', 'Heart - Left Ventricle', 'Heart - Atrial Appendage', 'Lung', 'Adipose - Visceral (Omentum)', 'Prostate', 'Testis', 'Colon - Transverse', 'Esophagus - Mucosa', 'Esophagus - Muscularis', 'Stomach', 'Muscle - Skeletal', 'Skin - Sun Exposed (Lower leg)', 'Artery - Tibial', 'Pituitary', 'Adrenal Gland', 'Pancreas', 'Small Intestine - Terminal Ileum', 'Colon - Sigmoid', 'Heart - Atrial Appendage', 'Adipose - Visceral (Omentum)', 'Colon - Transverse', 'Stomach', 'Heart - Left Ventricle', 'Thyroid', 'Lung', 'Breast - Mammary Tissue', 'Pros ...

# %% [markdown]
# 3. Create a list of expression values for each gene in the `gene_tissue` dictionary (given at the start of the exercise), keeping only expression values from the tissue of interest for that gene
#
#     - Since the file is already open, you can keep reading lines from it in, picking up from after the last line read
#     - You will be log-transforming the expression data using the `log2` function from the built-in library `math`
#     - To deal with zeros in expression data, add one before log-transforming expression data

# %%
# Import the log2 function from the math library to transform the expression counts
from math import log2

# Create a dictionary to hold each gene's expression data
gene_expression = {}

# Because this is a large file, for testing purposes you can use only a small portion of the file to test your code
line_counter = 0

# Step through each line of the file
for line in gzip.open(expression_fname):

    ############# REMOVE THIS AND RERUN ONCE YOUR CODE IS WORKING ####################
    # For debugging, use only the first 500 lines of the file.
    line_counter += 1
    # if line_counter == 500:
    #     break
    ############# REMOVE THIS AND RERUN ONCE YOUR CODE IS WORKING ####################
    

    # Convert the line into a string from a byte string, remove the newline character at the end, and split it by tab characters
    fields = line.decode().rstrip().split("\t")

    # Check if this line contains data for a gene we are interested in. If not, skip it
    fields = line.decode().rstrip().split("\t")
    if fields[0] not in gene_tissue:
        continue

    # Determine which tissue we care about for this gene
    tissue = gene_tissue[fields[0]]

    # Create a list in the gene expression dictionary to hold the gene's data
    gene_expression[fields[0]] = []

    # Look at each column position, one by one
    for i in range(len(tissues)):

        # For each column, see if it is from the tissue we care about (using the tissues list). If so, add that field to our gene expression list, first transforming it with log2(1 + float(field[i])) 
        if tissues[i] == tissue:
            gene_expression[fields[0]].append(log2(1 + float(fields[i])))

# %% [markdown]
# 4. For each gene, calculate the mean, standard deviation, and relative standard deviation and write them to a results file
#
#     - You will be using the `mean` and `stdev` functions from the built-in `statistics` library. Both functions accept a list as their input
#     - Format your results for each gene into a string and write that string to your results file
#     - If you want to organize your results better (completely optional!!), you can save your results in a list and sorting them by tissue type before writing them to a file

# %%
len(gene_expression.keys())
# Out:
# 33

# %%
# Load the functions to caculcate the mean and standard deviation from a list
from statistics import stdev, mean

# Open a file to write the results to
with open('gene_stats.txt', 'w') as f:
# Step through each gene and its expression value list
    for gene in gene_expression:
        e_values = gene_expression[gene]
    # Calculate the mean and standard deviation of expression
        M = mean(e_values)
        STD = stdev(e_values)
    # Calculate the relative standard deviation (coefficient of variation, std / mean)
        RSTD = STD/M
    # Write the tissue name, gene name, mean, standard deviation, and relative standard deviation to your results file
        f.write("\t".join([gene_tissue[gene], str(gene), str(M), str(STD), str(RSTD)]))
        f.write("\n")
# Close your results file

# %% [markdown]
# 5. Looking at your results, answer the following questions
#
#     - Which tissues have low relative variability (rv < 0.2), medium relative variability (0.2 < rv < 0.4), or high relative variability (rv > 0.4)?
#     - Do each of the genes for a given tissue show the same level of relative variability?
#     - Propose an explanation for differences in relative variability you see between tissues based on what you know about their functions.
#     - Were any of the results surpising to you?

# %% [markdown]
# Answers:
